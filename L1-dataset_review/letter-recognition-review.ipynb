# %% [markdown]
# # Letter recognition data review
#
# Brief overview

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('../dataset/letter-recognition.data', sep = ',', engine = 'python')

# %%
data.columns = [u'lettr', u'x-box', u'y-box', u'width', u'high',
       u'onpix', u'x-bar', u'y-bar', u'x2bar', u'y2bar',
       u'xybar', u'x2ybr', u'xy2br', u'x-ege',
       u'xegvy', u'y-ege', u'yegvx']

# %%
data
# Out:
#       lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  \
# 0         I      5     12      3     7      2     10      5      5      4
# 1         D      4     11      6     8      6     10      6      2      6
# 2         N      7     11      6     6      3      5      9      4      6
# 3         G      2      1      3     1      1      8      6      6      6
# 4         S      4     11      5     8      3      8      8      6      9
# 5         B      4      2      5     4      4      8      7      6      6
# 6         A      1      1      3     2      1      8      2      2      2
# 7         J      2      2      4     4      2     10      6      2      6
# 8         M     11     15     13     9      7     13      2      6      2
# 9         X      3      9      5     7      4      8      7      3      8
# 10        O      6     13      4     7      4      6      7      6      3
# 11        G      4      9      6     7      6      7      8      6      2
# ...

# %%
data.head()
# Out:
#   lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0     I      5     12      3     7      2     10      5      5      4     13
# 1     D      4     11      6     8      6     10      6      2      6     10
# 2     N      7     11      6     6      3      5      9      4      6      4
# 3     G      2      1      3     1      1      8      6      6      6      6
# 4     S      4     11      5     8      3      8      8      6      9      5
#
#    x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0      3      9      2      8      4     10
# 1      3      7      3      7      3      9
# 2      4     10      6     10      2      8
# 3      5      9      1      7      5     10
# 4      6      6      0      8      9      7

# %%
data.tail()
# Out:
#       lettr  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  \
# 19994     D      2      2      3     3      2      7      7      7      6
# 19995     C      7     10      8     8      4      4      8      6      9
# 19996     T      6      9      6     7      5      6     11      3      7
# 19997     S      2      3      4     2      1      8      7      2      6
# 19998     A      4      9      6     6      2      9      5      3      1
#
#        xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 19994      6      6      4      2      8      3      7
# 19995     12      9     13      2      9      3      7
# 19996     11      9      5      2     12      2      4
# 19997     10      6      8      1      9      5      8
# 19998      8      1      8      2      7      2      8

# %% [markdown]
# ```
# 1.	lettr	capital letter					(26 values from A to Z)
# 2.	x-box	horizontal position of box		(integer)
# 3.	y-box	vertical position of box		(integer)
# 4.	width	width of box					(integer)
# 5.	high 	height of box					(integer)
# 6.	onpix	total # on pixels				(integer)
# 7.	x-bar	mean x of on pixels in box		(integer)
# 8.	y-bar	mean y of on pixels in box		(integer)
# 9.	x2bar	mean x variance					(integer)
# 10.	y2bar	mean y variance					(integer)
# 11.	xybar	mean x y correlation			(integer)
# 12.	x2ybr	mean of x * x * y				(integer)
# 13.	xy2br	mean of x * y * y				(integer)
# 14.	x-ege	mean edge count left to right	(integer)
# 15.	xegvy	correlation of x-ege with y		(integer)
# 16.	y-ege	mean edge count bottom to top	(integer)
# 17.	yegvx	correlation of y-ege with x		(integer)
# ```

# %%
print(data.shape)
print(data.columns)
# Out:
# (19999, 17)
# Index(['lettr', 'x-box', 'y-box', 'width', 'high', 'onpix', 'x-bar', 'y-bar',
#        'x2bar', 'y2bar', 'xybar', 'x2ybr', 'xy2br', 'x-ege', 'xegvy', 'y-ege',
#        'yegvx'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=19999, step=1)

# %% [markdown]
# # Let's take a look at data dependencies

# %%
data.describe()
# Out:
#               x-box         y-box         width          high         onpix  \
# count  19999.000000  19999.000000  19999.000000  19999.000000  19999.000000
# mean       4.023651      7.035452      5.121956      5.372469      3.505975
# std        1.913206      3.304631      2.014568      2.261445      2.190441
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      5.000000      4.000000      4.000000      2.000000
# 50%        4.000000      7.000000      5.000000      6.000000      3.000000
# 75%        5.000000      9.000000      6.000000      7.000000      5.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#               x-bar         y-bar         x2bar         y2bar         xybar  \
# count  19999.000000  19999.000000  19999.000000  19999.000000  19999.000000
# mean       6.897545      7.500175      4.628831      5.178609      8.282164
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (20, 20))
pass

# %% [markdown]
# Dataset provides only some of numerical datas, which was obtained after processing of original data (letter images). So, there is no interesting to compare between data.
#
# В датасете содержатся только численные данные, полученные путём обработки буквенных изображений. Так что мало смысла в графическом сравнении их между собой.

# %% [markdown]
# But, let's try to find datas, which is correlated with each another most.
#
# Но, возможно, в датасете присутствуют данные, сильно коррелирующие между собой.

# %%
data.corr()
# Out:
#           x-box     y-box     width      high     onpix     x-bar     y-bar  \
# x-box  1.000000  0.757831  0.851506  0.672774  0.619074 -0.032567  0.045678
# y-box  0.757831  1.000000  0.671947  0.823212  0.555103  0.045682 -0.040966
# width  0.851506  0.671947  1.000000  0.660225  0.765702  0.061989  0.024960
# high   0.672774  0.823212  0.660225  1.000000  0.644378  0.042849 -0.020055
# onpix  0.619074  0.555103  0.765702  0.644378  1.000000  0.139196 -0.028692
# x-bar -0.032567  0.045682  0.061989  0.042849  0.139196  1.000000 -0.356697
# y-bar  0.045678 -0.040966  0.024960 -0.020055 -0.028692 -0.356697  1.000000
# x2bar  0.014217 -0.024996 -0.098711  0.082375 -0.012084 -0.053264 -0.118447
# y2bar  0.052106  0.096473  0.057094  0.059035 -0.065540 -0.122861 -0.049706
# xybar  0.148015  0.159971  0.114976  0.012450 -0.069833  0.085991  0.178455
# x2ybr  0.035538 -0.054671  0.011766 -0.011981 -0.072870 -0.342012  0.600349
# ...

# %% [markdown]
# Unfortunately, it's complicated to find some correlated rows in data view like this.
#
# Увы, в таком виде не совсем удобно смотреть зависимые столбцы.

# %%
type(data.corr())
# Out:
# pandas.core.frame.DataFrame

# %%
data.corr().abs().unstack().sort_values(kind="quicksort", ascending=False)
# Out:
# yegvx  yegvx    1.000000
# y-ege  y-ege    1.000000
# y-box  y-box    1.000000
# width  width    1.000000
# high   high     1.000000
# onpix  onpix    1.000000
# x-bar  x-bar    1.000000
# y-bar  y-bar    1.000000
# x2bar  x2bar    1.000000
# y2bar  y2bar    1.000000
# xybar  xybar    1.000000
# x2ybr  x2ybr    1.000000
# xy2br  xy2br    1.000000
# x-ege  x-ege    1.000000
# xegvy  xegvy    1.000000
# x-box  x-box    1.000000
# width  x-box    0.851506
# x-box  width    0.851506
# y-box  high     0.823212
# high   y-box    0.823212
# onpix  width    0.765702
# width  onpix    0.765702
# x-box  y-box    0.757831
# y-box  x-box    0.757831
# x-box  high     0.672774
# high   x-box    0.672774
# width  y-box    0.671947
# y-box  width    0.671947
# width  high     0.660225
# high   width    0.660225
#                   ...
# x2bar  y-box    0.024996
# y-box  x2bar    0.024996
# width  y-bar    0.024960
# y-bar  width    0.024960
# high   y-bar    0.020055
# y-bar  high     0.020055
# ...

# %% [markdown]
# Data with correlation above 0,7 looks suspiciously, but for now, let's not pay attention to that fact.
#
# Данные с корреляцией выше 0.7 выглядят подозрительно, но пока не будем обращать на это внимания.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# For the start, I prefer to check is data really full, and don't have any null rows.
#
# Проверим для спокойствия, что все данные на месте и пропусков нет.

# %%
data.isnull().sum()
# Out:
# lettr    0
# x-box    0
# y-box    0
# width    0
# high     0
# onpix    0
# x-bar    0
# y-bar    0
# x2bar    0
# y2bar    0
# xybar    0
# x2ybr    0
# xy2br    0
# x-ege    0
# xegvy    0
# y-ege    0
# yegvx    0
# dtype: int64

# %% [markdown]
# All ok, let's split original dataset to train and test set.
#
# Всё в порядке, разобьём теперь датасет на тренировочную и тестовую выборку.

# %% [markdown]
# ### Split to X and y

# %%
X = data.drop(('lettr'), axis = 1)
y = data['lettr']
feature_names = X.columns

# %%
X.head()
# Out:
#    x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  x2ybr  \
# 0      5     12      3     7      2     10      5      5      4     13      3
# 1      4     11      6     8      6     10      6      2      6     10      3
# 2      7     11      6     6      3      5      9      4      6      4      4
# 3      2      1      3     1      1      8      6      6      6      6      5
# 4      4     11      5     8      3      8      8      6      9      5      6
#
#    xy2br  x-ege  xegvy  y-ege  yegvx
# 0      9      2      8      4     10
# 1      7      3      7      3      9
# 2     10      6     10      2      8
# 3      9      1      7      5     10
# 4      6      0      8      9      7

# %%
y.head()
# Out:
# 0    I
# 1    D
# 2    N
# 3    G
# 4    S
# Name: lettr, dtype: object

# %%
#Sklearn, join us on this journey
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_test.head()
# Out:
#        x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 10650      0      0      1     0      0      7      7      3      5      7
# 2041       5     10      7     8      6      6      8      5      6      6
# 8668       4      5      5     4      3      5     10      4      5     10
# 1114       7     13      6     7      3     12      5      2      6     12
# 13902      1      7      2     5      1      7      7      0      7     13
#
#        x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 10650      6      8      2      8      3      8
# 2041       5      8      3      6      6      9
# 8668       8      3      1     10      3      7
# 1114       3      6      2     10      4     12
# 13902      6      8      0      8      1      8

# %%
y_train.value_counts().sort_index()
# Out:
# A    538
# B    523
# C    507
# D    536
# E    504
# F    513
# G    518
# H    485
# I    527
# J    505
# K    506
# L    494
# M    537
# N    510
# O    496
# P    542
# Q    521
# R    502
# S    508
# T    539
# U    562
# V    496
# W    492
# X    516
# Y    537
# Z    485
# Name: lettr, dtype: int64

# %%
y_test.value_counts().sort_index()
# Out:
# A    251
# B    243
# C    229
# D    269
# E    264
# F    262
# G    255
# H    249
# I    228
# J    242
# K    233
# L    267
# M    255
# N    273
# O    257
# P    261
# Q    262
# R    256
# S    240
# T    256
# U    251
# V    268
# W    260
# X    271
# Y    249
# Z    249
# Name: lettr, dtype: int64

# %% [markdown]
# ## Example of some algorithm

# %% [markdown]
# ### K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 15)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=15, p=2,
#            weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print("Train error: {}\n Test error: {}".format(err_train, err_test))
# Out:
# Train error: 0.05231733711471005
#  Test error: 0.07757575757575758

# %% [markdown]
# Looks good, what about another parameters?
#
# Выглядит неплохо, а что если использовать другие параметры?

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.04851108291663553 1

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print("Train error: {}\n Test error: {}".format(err_train, err_test))
# Out:
# Train error: 0.0
#  Test error: 0.04772727272727273

# %% [markdown]
# ### Random forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print("Train error: {}\n Test error: {}".format(err_train, err_test))
# Out:
# Train error: 0.0
#  Test error: 0.03742424242424242

# %% [markdown]
# Ok, it looks too good. Investigating, what I may do wrong.
#
# Окей, выглядит слишком хорошо. Возможно, что-то делаю не так.
